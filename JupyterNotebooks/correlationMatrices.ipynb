# %%
import pandas as pd

# !pip install seaborn --upgrade

df = pd.read_csv('https://raw.githubusercontent.com/fantasydatapros/LearnPythonWithFantasyFootball/master/2023/08-Correlation%20Matrices/weekly_df.csv')
print(df.shape)
df.head()
# Out:
# Requirement already satisfied: seaborn in c:\users\mikec\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\mikec\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\mikec\anaconda3\lib\site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\mikec\anaconda3\lib\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mikec\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mikec\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mikec\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mikec\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\mikec\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mikec\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mikec\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mikec\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mikec\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\mikec\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\mikec\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# (5629, 40)
#      PlayerID     Player Position  Tm  Week  PassingYds  PassingAirYards  \
# 0  00-0019596  Tom Brady       QB  TB     1         212              305
# 1  00-0019596  Tom Brady       QB  TB     2         190              318
# 2  00-0019596  Tom Brady       QB  TB     3         271              236
# 3  00-0019596  Tom Brady       QB  TB     4         385              326
# 4  00-0019596  Tom Brady       QB  TB     5         351              356
#
#    PassingYAC  PassingTD  Sacks  ...  ReceivingEPA  Receiving2PC  TargetShare  \
# 0          87          1      2  ...           NaN             0          NaN
# 1          81          1      1  ...           NaN             0          NaN
# 2         124          1      3  ...           NaN             0          NaN
# 3         205          3      1  ...           NaN             0          NaN
# 4         178          1      0  ...           NaN             0          NaN
#
#    AirYardsShare  WOPR  SpecialTeamsTD  FumblesLost  StandardFantasyPoints  \
# 0            NaN   NaN               0            0                  10.38
# 1            NaN   NaN               0            1                   9.40
# 2            NaN   NaN               0            0                  14.74
# 3            NaN   NaN               0            1                  25.40
# 4            NaN   NaN               0            0                  19.74
#
#    PPRFantasyPoints  HalfPPRFantasyPoints
# 0             10.38                 10.38
# 1              9.40                  9.40
# 2             14.74                 14.74
# 3             25.40                 25.40
# 4             19.74                 19.74
#
# [5 rows x 40 columns]

# %%
df['Position'].unique()
# Out:
# array(['QB', 'P', 'TE', 'WR', 'RB', 'ILB', 'FB', 'T', 'FS', 'SS', 'OLB',
#        'CB'], dtype=object)

# %%
skill_positions = ['QB', 'TE', 'RB', 'WR']

#isin allows us to filter out row values who's given column value
#is within a list of values.

df = df.loc[df['Position'].isin(skill_positions)]

df.tail()
# Out:
#         PlayerID          Player Position   Tm  Week  PassingYds  \
# 5624  00-0038134  Kenneth Walker       RB  SEA    17           0
# 5625  00-0038134  Kenneth Walker       RB  SEA    18           0
# 5626  00-0038134  Kenneth Walker       RB  SEA    19           0
# 5627  00-0038147  Daylen Baldwin       WR  CLE    15           0
# 5628  00-0038149        Josh Ali       WR  ATL    18           0
#
#       PassingAirYards  PassingYAC  PassingTD  Sacks  ...  ReceivingEPA  \
# 5624                0           0          0      0  ...      0.968106
# 5625                0           0          0      0  ...      0.430252
# 5626                0           0          0      0  ...     -0.309929
# 5627                0           0          0      0  ...      1.791362
# 5628                0           0          0      0  ...     -0.519020
#
#       Receiving2PC  TargetShare  AirYardsShare      WOPR  SpecialTeamsTD  \
# 5624             0     0.035714      -0.003717  0.050969               0
# 5625             0     0.035714      -0.003745  0.050950               0
# 5626             0     0.029412       0.000000  0.044118               0
# 5627             0     0.076923       0.223214  0.271635               0
# 5628             0     0.035714       0.137615  0.149902               0
#
#       FumblesLost  StandardFantasyPoints  PPRFantasyPoints  \
# 5624            0                   14.2              15.2
# 5625            0                   12.4              13.4
# 5626            0                   12.6              13.6
# 5627            0                    2.5               4.5
# 5628            0                    0.0               0.0
#
#       HalfPPRFantasyPoints
# 5624                  14.7
# 5625                  12.9
# 5626                  13.1
# 5627                   3.5
# 5628                   0.0
#
# [5 rows x 40 columns]

# %%
df.shape
# Out:
# (5495, 40)

# %%
import numpy as np

columns = ['Player', 'Tm', 'Position', 'Week', 'PPRFantasyPoints']

new_df = df[columns]
new_df.head()
# Out:
#       Player  Tm Position  Week  PPRFantasyPoints
# 0  Tom Brady  TB       QB     1             10.38
# 1  Tom Brady  TB       QB     2              9.40
# 2  Tom Brady  TB       QB     3             14.74
# 3  Tom Brady  TB       QB     4             25.40
# 4  Tom Brady  TB       QB     5             19.74

# %%
new_df = new_df.groupby(['Player', 'Tm', 'Position'], as_index=False).agg({
    'PPRFantasyPoints': np.mean
    
})

new_df.head()
# Out:
# C:\Users\mikec\AppData\Local\Temp\ipykernel_28280\3910443706.py:1: FutureWarning: The provided callable <function mean at 0x000001CEE5775620> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   new_df = new_df.groupby(['Player', 'Tm', 'Position'], as_index=False).agg({
#           Player   Tm Position  PPRFantasyPoints
# 0     A.J. Brown  PHI       WR         16.660000
# 1    A.J. Dillon   GB       RB          9.858824
# 2     A.J. Green  ARI       WR          4.738462
# 3    Aaron Jones   GB       RB         14.623529
# 4  Aaron Rodgers   GB       QB         14.070588

# %%
new_df.loc[(new_df['Position'] == 'WR') & (new_df['Tm'] == 'ARI')].sort_values(by= 'PPRFantasyPoints', ascending=False)
# Out:
#               Player   Tm Position  PPRFantasyPoints
# 159  DeAndre Hopkins  ARI       WR         16.855556
# 396   Marquise Brown  ARI       WR         13.000000
# 490    Rondale Moore  ARI       WR         10.987500
# 219      Greg Dortch  ARI       WR         10.463636
# 2         A.J. Green  ARI       WR          4.738462
# 18   Andre Baccellia  ARI       WR          2.300000
# 484   Robby Anderson  ARI       WR          2.085714
# 21     Andy Isabella  ARI       WR          2.050000
# 461    Pharoh Cooper  ARI       WR          2.050000

# %%
position_map = {
    'QB': 1,
    'RB':2,
    'WR':3,
    'TE':2
}

def get_top_n_player_at_each_position(df, pos, n):
    df = df.loc[df['Position'] == pos]
    
    return df.groupby('Tm', as_index=True).apply(
        lambda x: x.nlargest(n, ['PPRFantasyPoints']).min()
    )

# get_top_n_player_at_each_position(new_df, 'WR', n=1)

corr_df = pd.DataFrame(columns=columns)

for pos, n_spots in position_map.items():
    for n in range(1, n_spots + 1):
        pos_df = get_top_n_player_at_each_position(new_df, pos, n)
        pos_df = pos_df.rename({'PPRFantasyPoints': f'{pos}{n}'}, axis=1)
        corr_df = pd.concat([corr_df, pos_df], axis=1)
corr_df = corr_df.dropna(axis=1)
corr_df = corr_df.drop(['Position', 'Player', 'Tm'], axis=1)
corr_df.head(32)
# Out:
#            QB1        RB1        RB2        WR1        WR2        WR3  \
# ARI  18.229091  15.400000   9.588889  16.855556  13.000000  10.987500
# ATL  15.120000  11.900000   9.962500  10.505882   6.875000   4.577778
# BAL  19.673333  11.300000   8.675000   8.916667   8.292857   6.864706
# BUF  24.155556  10.772222   6.494444  19.027778  11.782353   8.100000
# CAR  14.386667  19.666667   8.187500  11.711765   7.520000   6.384615
# CHI  19.732000  11.106250   9.061538   9.227273   4.657143   4.437500
# CIN  21.396842  16.164706   8.705263  19.780000  15.100000   9.580000
# CLE  14.263333  16.552941   7.458824  14.470588   9.829412   4.500000
# DAL  17.545714  14.777778  11.511765  17.931579   7.562500   7.200000
# DEN  15.050667  11.725000  10.500000  13.613333  10.626667   5.127273
# DET  16.724706  13.650000  13.288235  16.725000   8.927273   8.658333
# GB   14.070588  14.623529   9.858824  11.721429  11.653333   7.815385
# HOU  12.101333  12.800000   4.760000  11.200000   9.710000   7.673333
# IND  12.940000  13.309091   7.628571  13.531250   8.770588   7.018750
# JAX  17.432632  12.273684  10.228571  15.036842  12.933333   7.327778
# KC   23.876000  10.530000   9.830000  10.833333  10.747368   7.680000
# LA   12.042222   9.420000   7.350000  22.377778   8.490000   7.890000
# LAC  16.521111  21.722222   5.276923  16.009091  13.576923  10.258824
# LV   14.605333  19.311765   4.161538  19.735294   9.068235   7.900000
# MIA  17.763077  10.577778  10.518750  19.866667  14.855556   4.923529
# MIN  17.633333  13.933333   4.977778  21.126667  10.444444   9.200000
# NE   12.148571  14.652941   8.263636  13.164286  10.300000   8.575000
# NO   14.640000  14.113333  13.500000  17.033333  13.213333   9.136364
# NYG  20.820000  17.894444   3.778947  11.790000  11.466667   9.856250
# NYJ  14.145000  16.442857   8.428571  12.705882   7.507692   6.292857
# PHI  25.416667  12.240000   6.225000  16.660000  14.815000   4.794444
# PIT  11.527692  13.144706   6.233333  10.629412   9.830000   9.794118
# SEA  17.822222  13.506250  10.440000  14.658824  14.577778   7.516667
# SF   14.980000  21.304286  11.000000  13.118750  12.235000   5.183333
# TB   16.316667  13.458824   8.988235  15.081250  15.050000   9.042857
# TEN  13.770000  18.922500   7.018182   8.009091   6.923529   5.513333
# WAS  18.260000  11.060000   9.391667  13.470588  10.883333  10.370588
#
#            TE1       TE2
# ARI  11.560000  6.833333
# ATL   7.560000  5.500000
# BAL  12.675000  8.900000
# BUF   9.305882  3.025000
# CAR   3.885714  3.130769
# CHI   8.664706  1.650000
# CIN   8.531250  3.709091
# CLE  10.142857  4.407143
# DAL  10.876471  4.400000
# DEN   8.610000  4.250000
# DET  12.214286  5.125000
# GB    6.588235  4.433333
# HOU   7.766667  4.733333
# IND   6.183333  4.707692
# JAX  10.910526  2.250000
# KC   19.650000  3.835000
# LA    9.500000  2.750000
# LAC  10.150000  5.042857
# LV   10.600000  6.214286
# MIA   5.983333  3.307692
# MIN  13.890909  6.944444
# NE    6.493750  4.333333
# NO    9.112500  8.425000
# NYG   6.623077  4.971429
# NYJ   7.735294  4.683333
# PHI  11.820000  2.620000
# PIT   9.880000  4.475000
# SEA   7.700000  6.927778
# SF   12.738889  4.875000
# TB    6.860000  4.520000
# TEN   6.480000  5.729412
# WAS   5.946154  3.422222

# %%
type(corr_df)
# Out:
# pandas.core.frame.DataFrame

# %%
import seaborn as sns
import matplotlib

from matplotlib import pyplot as plt

sns.set_style('whitegrid')
plt.figure(figsize=(12,9))
sns.heatmap(
    corr_df.corr(), annot=True, cmap=sns.diverging_palette(0,250, as_cmap=True), fmt=".2f",
    annot_kws={"size": 10},
    linecolor='gray'
)
plt.title('Heatmap of Correlation Matrix')
plt.show()
